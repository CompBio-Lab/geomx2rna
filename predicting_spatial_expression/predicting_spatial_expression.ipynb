# %%
import pandas as pd

# %%
import os

os.getcwd()

def reformat(column_name):
    id = column_name.split("|")
    x = id[0]
    y = str(int(id[1]))
    return ''.join([x, y]).replace(' ', '')
# Out:
# '/scratch/st-singha53-1/singha53/geomx2rna/predicting_spatial_expression'

# %%
eset = pd.read_csv("data/Kidney_Q3Norm_TargetCountMatrix.txt", delimiter="\t")

# %%
eset.head()
# Out:
#   TargetName  disease3_scan | 001 | PanCK  disease3_scan | 001 | neg  \
# 0      PADI2                     6.012910                   8.618505
# 1    CYP24A1                     9.219796                   7.879776
# 2    SUPT16H                    14.030124                  16.252038
# 3      ZMIZ2                    20.443895                  19.945682
# 4      SPAG9                    19.241313                  16.005795
#
#    disease3_scan | 002 | PanCK  disease3_scan | 002 | neg  \
# 0                    11.708157                   8.314322
# 1                     7.480212                   8.314322
# 2                    14.960423                  12.370089
# 3                    28.294714                  22.915083
# 4                    14.960423                  18.453740
#
#    disease3_scan | 003 | PanCK  disease3_scan | 003 | neg  \
# 0                     5.171103                  12.264795
# 1                     1.723701                   9.944429
# ...

# %%
[reformat(x) for x in list(eset.columns)[1:]]
# Out:
# ['disease3_scan1',
#  'disease3_scan1',
#  'disease3_scan2',
#  'disease3_scan2',
#  'disease3_scan3',
#  'disease3_scan3',
#  'disease3_scan4',
#  'disease3_scan4',
#  'disease3_scan5',
#  'disease3_scan5',
#  'disease3_scan6',
#  'disease3_scan6',
#  'disease3_scan7',
#  'disease3_scan8',
#  'disease3_scan9',
#  'disease3_scan10',
#  'disease3_scan11',
#  'disease3_scan12',
#  'disease3_scan13',
#  'disease3_scan14',
#  'disease3_scan15',
#  'disease3_scan16',
#  'disease3_scan17',
#  'disease3_scan18',
#  'disease3_scan19',
#  'disease3_scan20',
#  'disease3_scan21',
#  'disease3_scan22',
#  'disease3_scan23',
#  'disease3_scan24',
#  'disease3_scan25',
#  'disease3_scan26',
#  'disease3_scan27',
#  'disease3_scan28',
#  'disease3_scan29',
#  'disease3_scan30',
#  'disease3_scan31',
#  'disease3_scan32',
#  'disease3_scan33',
#  'disease3_scan34',
#  'disease3_scan35',
#  'disease3_scan36',
#  'disease3_scan37',
#  'disease3_scan38',
#  'disease3_scan39',
#  'disease3_scan40',
# ...
